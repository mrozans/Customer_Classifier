# %%
import pandas as pd
import numpy as np
import DataLoad as data

# %%
sessions = data.load_sessions_data()
users = data.load_users_data()
products = data.load_products_data()

# %%
sessions
# Out:
#        session_id           timestamp  user_id  product_id  offered_discount  \
# 0          100001 2020-01-15 13:44:51    102.0      1017.0                 0
# 1          100001 2020-01-15 13:48:01    102.0      1025.0                 0
# 2          100001 2020-01-15 13:49:47    102.0      1030.0                 0
# 3          100001 2020-01-15 13:50:34    102.0      1032.0                 0
# 4          100001 2020-01-15 13:52:02    102.0      1033.0                 0
# ...           ...                 ...      ...         ...               ...
# 55105      110273 2020-02-17 03:13:41    301.0      1012.0                15
# 55106      110273 2020-02-17 03:17:18    301.0      1013.0                15
# 55107      110274 2020-02-29 22:45:54      NaN      1001.0                 0
# 55108      110275 2020-01-24 18:01:37    301.0      1283.0                 0
# 55109      110276 2020-03-26 12:37:51    301.0      1283.0                10
#
#        purchase_id  event_type_BUY_PRODUCT  event_type_VIEW_PRODUCT
# 0              NaN                       0                        1
# 1              NaN                       0                        1
# 2              NaN                       0                        1
# 3              NaN                       0                        1
# 4              NaN                       0                        1
# ...            ...                     ...                      ...
# 55105          NaN                       0                        1
# 55106          NaN                       0                        1
# 55107          NaN                       0                        1
# 55108          NaN                       0                        1
# 55109          NaN                       0                        1
#
# [55110 rows x 8 columns]

# %%
def fav_categories(uid, sessions_df, products_df):
    products_id = sessions_df.loc[sessions_df['user_id'] == uid]['product_id']
    fav = products_df.loc[products_df['product_id'].isin(products_id.tolist())]
    fav = fav[fav.columns[3:]]
    return fav.sum()

# %%
def favourite_products(users_df, sessions_df, products_df):
    arr = np.zeros(shape =(len(users_df['user_id']), 28))
    j = 0
    for i in users_df['user_id']:
        arr[j] = fav_categories(i, sessions_df, products_df)
        j += 1
    fv =  fav_categories(102, sessions_df, products_df)
    for k in range(len(fv.index.tolist())):
        users_df[fv.index.tolist()[k]] = arr[:, k]
    return users_df

# %%
fprod = favourite_products(users, sessions, products)
for k in range(len(fv.index.tolist())):
    users2[fv.index.tolist()[k]] = fprod[:, k]

# %%
fav_categories(300, sessions, products)
# Out:
# Telefony i akcesoria                 11
# Telefony stacjonarne                  1
# Komputery                            21
# Drukarki i skanery                    9
# Biurowe urządzenia wielofunkcyjne     9
# Gry i konsole                        19
# Gry na konsole                        9
# Gry Xbox 360                          0
# Monitory                             10
# Monitory LCD                         10
# Telefony komórkowe                    2
# Gry PlayStation3                      9
# Gry komputerowe                      10
# Akcesoria telefoniczne                8
# Zestawy głośnomówiące                 5
# Sprzęt RTV                           14
# Video                                11
# Odtwarzacze DVD                       2
# Tablety i akcesoria                   2
# Tablety                               2
# Przenośne audio i video               2
# Odtwarzacze mp3 i mp4                 2
# Telewizory i akcesoria                9
# Okulary 3D                            1
# Anteny RTV                            8
# Zestawy słuchawkowe                   3
# Audio                                 1
# Słuchawki                             1
# dtype: int64

# %%
users2
# Out:
#      user_id               name      city                street  \
# 0        102   Agnieszka Heczko     Kutno  al. Malczewskiego 43
# 1        103   Sandra Ostapczuk     Radom      ul. Błękitna 352
# 2        104        Kamila Buza  Warszawa          pl. Orla 450
# 3        105        Alan Daniec    Gdynia          ul. Reja 326
# 4        106     Natasza Pasiut     Radom     al. Poziomkowa 43
# ..       ...                ...       ...                   ...
# 195      297  Igor Gryszkiewicz  Warszawa    plac Pułaskiego 26
# 196      298       Maurycy Klęk     Radom     aleja Średnia 817
# 197      299      Ada Malcharek    Mielec  ulica Sikorskiego 14
# 198      300  Kajetan Kuropatwa    Mielec     ulica Złota 76/64
# 199      301     Stefan Suchora    Police     aleja Brzechwy 23
#
#      Telefony i akcesoria  Telefony stacjonarne  Komputery  \
# 0                     8.0                   1.0       19.0
# 1                    12.0                   1.0       21.0
# 2                    12.0                   1.0       21.0
# 3                    12.0                   1.0       21.0
# 4                    12.0                   1.0       21.0
# ..                    ...                   ...        ...
# 195                  12.0                   1.0       21.0
# 196                  12.0                   1.0       21.0
# 197                   6.0                   0.0       12.0
# 198                  11.0                   1.0       21.0
# 199                  12.0                   1.0       21.0
#
#      Drukarki i skanery  Biurowe urządzenia wielofunkcyjne  Gry i konsole  \
# 0                   9.0                                9.0           29.0
# 1                   9.0                                9.0           29.0
# 2                   9.0                                9.0           29.0
# 3                   9.0                                9.0           29.0
# 4                   9.0                                9.0           27.0
# ..                  ...                                ...            ...
# 195                 9.0                                9.0           29.0
# 196                 9.0                                9.0           29.0
# 197                 0.0                                0.0            9.0
# 198                 9.0                                9.0           19.0
# 199                 9.0                                9.0           29.0
#
#      ...  Tablety i akcesoria  Tablety  Przenośne audio i video  \
# 0    ...                  0.0      0.0                      0.0
# 1    ...                  2.0      2.0                      2.0
# 2    ...                  2.0      2.0                      2.0
# 3    ...                  2.0      2.0                      2.0
# 4    ...                  2.0      2.0                      2.0
# ..   ...                  ...      ...                      ...
# 195  ...                  2.0      2.0                      2.0
# 196  ...                  2.0      2.0                      2.0
# 197  ...                  2.0      2.0                      2.0
# 198  ...                  2.0      2.0                      2.0
# 199  ...                  2.0      2.0                      2.0
#
#      Odtwarzacze mp3 i mp4  Telewizory i akcesoria  Okulary 3D  Anteny RTV  \
# 0                      0.0                     8.0         1.0         7.0
# 1                      2.0                    11.0         1.0        10.0
# 2                      2.0                    11.0         1.0        10.0
# 3                      2.0                    11.0         1.0        10.0
# 4                      2.0                    11.0         1.0        10.0
# ..                     ...                     ...         ...         ...
# 195                    2.0                    11.0         1.0        10.0
# 196                    2.0                    10.0         1.0         9.0
# 197                    2.0                     9.0         0.0         9.0
# 198                    2.0                     9.0         1.0         8.0
# 199                    2.0                    11.0         1.0        10.0
#
#      Zestawy słuchawkowe  Audio  Słuchawki
# 0                    0.0    1.0        1.0
# 1                    4.0    1.0        1.0
# 2                    4.0    1.0        1.0
# 3                    4.0    1.0        1.0
# 4                    4.0    1.0        1.0
# ..                   ...    ...        ...
# 195                  4.0    1.0        1.0
# 196                  4.0    1.0        1.0
# 197                  4.0    1.0        1.0
# 198                  3.0    1.0        1.0
# 199                  4.0    1.0        1.0
#
# [200 rows x 32 columns]

# %%
users_df = users
sessions_df = sessions
products_df = products

# %%
df = pd.DataFrame()
for i in users_df['user_id']:
    fav = fav_categories(i, sessions_df, products_df)
    df.append(fav)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f59d6ff3d20f> in <module>
#       2 for i in users_df['user_id']:
#       3     fav = fav_categories(i, sessions_df, products_df)
# ----> 4     df.append(fav)
#
# c:\users\łukasz\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7047             if other.name is None and not ignore_index:
#    7048                 raise TypeError(
# -> 7049                     "Can only append a Series if ignore_index=True "
#    7050                     "or if the Series has a name"
#    7051                 )
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
fv = fav_categories(102, sessions, products)
len(fv.index.tolist())
# Out:
# 28

# %%
fv.values.tolist()
# Out:
# [8,
#  1,
#  19,
#  9,
#  9,
#  29,
#  19,
#  10,
#  10,
#  10,
#  2,
#  9,
#  10,
#  5,
#  5,
#  11,
#  10,
#  2,
#  0,
#  0,
#  0,
#  0,
#  8,
#  1,
#  7,
#  0,
#  1,
#  1]

# %%
users[fv.index.tolist()] =
# Out:
#      user_id               name      city                street
# 0        102   Agnieszka Heczko     Kutno  al. Malczewskiego 43
# 1        103   Sandra Ostapczuk     Radom      ul. Błękitna 352
# 2        104        Kamila Buza  Warszawa          pl. Orla 450
# 3        105        Alan Daniec    Gdynia          ul. Reja 326
# 4        106     Natasza Pasiut     Radom     al. Poziomkowa 43
# ..       ...                ...       ...                   ...
# 195      297  Igor Gryszkiewicz  Warszawa    plac Pułaskiego 26
# 196      298       Maurycy Klęk     Radom     aleja Średnia 817
# 197      299      Ada Malcharek    Mielec  ulica Sikorskiego 14
# 198      300  Kajetan Kuropatwa    Mielec     ulica Złota 76/64
# 199      301     Stefan Suchora    Police     aleja Brzechwy 23
#
# [200 rows x 4 columns]
