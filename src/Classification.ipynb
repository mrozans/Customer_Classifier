# %%
import pandas as pd
import numpy as np
from scipy.special import softmax
import DataLoad as data
from sklearn.ensemble import RandomForestClassifier

# %%
sessions = data.load_sessions_data()
users = data.load_users_data()
products = data.load_products_data()

# %%
users = data.favourite_products(users, sessions, products)

# %%
users = data.spendings(users, sessions, products)

# %%
users = data.discounts_stats(users, sessions)

# %%
users = data.discounts_label(users, sessions)

# %%
users
# Out:
#      user_id               name      city                street  \
# 0        102   Agnieszka Heczko     Kutno  al. Malczewskiego 43
# 1        103   Sandra Ostapczuk     Radom      ul. Błękitna 352
# 2        104        Kamila Buza  Warszawa          pl. Orla 450
# 3        105        Alan Daniec    Gdynia          ul. Reja 326
# 4        106     Natasza Pasiut     Radom     al. Poziomkowa 43
# ..       ...                ...       ...                   ...
# 195      297  Igor Gryszkiewicz  Warszawa    plac Pułaskiego 26
# 196      298       Maurycy Klęk     Radom     aleja Średnia 817
# 197      299      Ada Malcharek    Mielec  ulica Sikorskiego 14
# 198      300  Kajetan Kuropatwa    Mielec     ulica Złota 76/64
# 199      301     Stefan Suchora    Police     aleja Brzechwy 23
#
#      Telefony i akcesoria  Telefony stacjonarne  Komputery  \
# 0            7.581872e-10          6.913772e-13   0.000045
# 1            4.138351e-08          6.911751e-13   0.000335
# ...

# %%
#users = users.set_index('user_id')
X = users[['Telefony i akcesoria',
       'Telefony stacjonarne', 'Komputery', 'Drukarki i skanery',
       'Biurowe urządzenia wielofunkcyjne', 'Gry i konsole', 'Gry na konsole',
       'Gry Xbox 360', 'Monitory', 'Monitory LCD', 'Telefony komórkowe',
       'Gry PlayStation3', 'Gry komputerowe', 'Akcesoria telefoniczne',
       'Zestawy głośnomówiące', 'Sprzęt RTV', 'Video', 'Odtwarzacze DVD',
       'Tablety i akcesoria', 'Tablety', 'Przenośne audio i video',
       'Odtwarzacze mp3 i mp4', 'Telewizory i akcesoria', 'Okulary 3D',
       'Anteny RTV', 'Zestawy słuchawkowe', 'Audio', 'Słuchawki', 'spendings',
       'm_accepted_discounts', 'm_rejected_discounts']]
X = X.fillna(0)

# %%
y = users['label']

# %%
clf = RandomForestClassifier(n_estimators=10, max_depth=3, random_state=0)

# %%
clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10, random_state=0)

# %%
x1 = X.loc[201,:].to_numpy()

# %%
x1 = x1.reshape(1, -1)

# %%
print(clf.predict(x1))
# Out:
# [0]

# %%
users.loc[201, 'label']
# Out:
# 1
